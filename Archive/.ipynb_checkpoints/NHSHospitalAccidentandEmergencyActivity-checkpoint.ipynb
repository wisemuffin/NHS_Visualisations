# %% [markdown]
# # Hospital Accident and Emergency Activity, 2016-17
# Publication date: 09:30 October 17, 2017
#
# https://digital.nhs.uk/catalogue/PUB30112
#
# This is a publication on Accident and Emergency (A&E) activity in English NHS hospitals and English NHS-commissioned activity in the independent sector.

# %% [markdown]
# ## Problem:
# The reporting is in depth but their doesnt seem to be much interactivity to allow the general public to explore the data.
#
# Aim to add the following functionality by using several libraries in Python:
# * Interactive charting with the use of plotly
# * Filters to slice and dice the data
# * Autocomplete for text filters

# %% [markdown]
# ## Find Datasets From NHS Digital Organisational Data Service
# Credit: psychemedia at https://github.com/psychemedia/python-pandas-datareader-NHSDigital/blob/master/docs/Testing%20-%20python-pandas-datareader-NHSDigital.ipynb

# %%
# pip install --force-reinstall --upgrade --no-deps git+https://github.com/psychemedia/python-pandas-datareader-NHSDigital.git

import pd_datareader_nhs.nhs_digital_ods as ods

# %% [markdown]
# NHS Organisational Data Service (ODS) publications available

# %%
publications=ods.search(string='')
#publications[publications["Type"] != 'health-authorities']
publications
# Out:
#           Dataset         Date  \
# 0        epraccur  24 Nov 2017
# 1          egpcur  24 Nov 2017
# 2        epracmem  24 Nov 2017
# 3          epcmem  24 Nov 2017
# 4        epracarc  24 Nov 2017
# 5          egparc  24 Nov 2017
# 6        ebranchs  24 Nov 2017
# 7     epharmacyhq  24 Nov 2017
# 8     edispensary  24 Nov 2017
# 9          enurse  24 Nov 2017
# 10          epcdp  24 Nov 2017
# 11    eabeydispgp  24 Nov 2017
# 12          egpam  15 Dec 2017
# 13       egpmemam  15 Dec 2017
# 14        epcdpam  15 Dec 2017
# 15          egpaq  24 Nov 2017
# 16       egpmemaq  24 Nov 2017
# 17        epcdpaq  24 Nov 2017
# 18           eccg  24 Nov 2017
# 19       eccgsite  24 Nov 2017
# 20            etr  24 Nov 2017
# 21            ets  24 Nov 2017
# 22         etrust  24 Nov 2017
# 23            ect  24 Nov 2017
# 24        ectsite  24 Nov 2017
# 25          ecare  24 Nov 2017
# 26           wlhb  24 Nov 2017
# 27       wlhbsite  24 Nov 2017
# 28           whbs  24 Nov 2017
# 29          eauth  24 Nov 2017
# ..            ...          ...
# 33         eother  24 Nov 2017
# 34           ensa  24 Nov 2017
# 35           ephp  24 Nov 2017
# 36       ephpsite  24 Nov 2017
# 37        enonnhs  24 Nov 2017
# 38    ecarehomehq  24 Nov 2017
# 39  ecarehomesite  30 Nov 2017
# 40  ecarehomesucc  24 Nov 2017
# 41       eschools  24 Nov 2017
# 42  educationtype  24 Nov 2017
# 43          Lauth  24 Nov 2017
# 44      Lauthsite  24 Nov 2017
# 45        eprison  24 Nov 2017
# 46       ejustice  24 Nov 2017
# 47         eopthq  24 Nov 2017
# 48       eoptsite  24 Nov 2017
# 49       egdpprac  25 Nov 2016
# 50           egdp  25 Nov 2016
# 51    egdppracmem  25 Nov 2016
# 52         etreat  24 Nov 2017
# 53       ehospice  24 Nov 2017
# 54          eplab  24 Nov 2017
# 55        educate  24 Nov 2017
# 56       earchive  24 Nov 2017
# 57           succ  24 Nov 2017
# 58        succarc  24 Nov 2017
# 59        econcur  15 Dec 2017
# 60       edconcur  15 Dec 2017
# 61        wconcur  24 Nov 2017
# 62        default  24 Nov 2017
# 54       miscellaneous   https://digital.nhs.uk/media/460/eplab/zip/eplab
# 55       miscellaneous  https://digital.nhs.uk/media/458/educate/zip/e...
# 56       miscellaneous  https://digital.nhs.uk/media/457/earchive/zip/...
# 57       miscellaneous     https://digital.nhs.uk/media/455/succ/zip/succ
# 58       miscellaneous  https://digital.nhs.uk/media/453/succarc/zip/s...
# 59       miscellaneous  https://digital.nhs.uk/media/450/econcur/zip/e...
# 60       miscellaneous  https://digital.nhs.uk/media/449/edconcur/zip/...
# 61       miscellaneous  https://digital.nhs.uk/media/448/wconcur/zip/w...
# 62       miscellaneous  https://digital.nhs.uk/media/447/default/zip/d...
#
# [63 rows x 6 columns]

# %%
# View whitelist of publications i.e. the most trustworthy publications
ods.dataset_codes
# Out:
# ['epraccur',
#  'etrust',
#  'eccg',
#  'eccgsite',
#  'epcmem',
#  'epracmem',
#  'egdpprac',
#  'egpcur',
#  'egparc',
#  'epracarc',
#  'ehospice',
#  'epharmacyhq',
#  'edispensary',
#  'enurse',
#  'epcdp',
#  'eabeydispgp',
#  'ecarehomehq',
#  'ecarehomesite',
#  'ecarehomesucc',
#  'ephp',
#  'ephpsite',
#  'enonnhs',
#  'eprison',
#  'eschools',
#  'ejustice',
#  'ecare']

# %%
ods.search(string='emer', field='Dataset')
# Out:
# Empty DataFrame
# Columns: [Dataset, Date, Label, Period, Type, URL]
# Index: []

# %% [markdown]
# # Setting Up

# %%
import pandas as pd

import pd_datareader_nhs.nhs_digital_ods as ods
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-0529076922b6> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 import pd_datareader_nhs.nhs_digital_ods as ods
#
# ModuleNotFoundError: No module named 'pd_datareader_nhs'

# %%
url = 'https://digital.nhs.uk/media/33253/Hospital-Accident-and-Emergency-Activity-2016-17-Provider-Level-Analysis/default/acci-emer-atte-eng-2016-17-pla'
AE_by_gender = pd.read_excel(url, sheet_name='Table_1', skiprows=5, header=1, names=("code", "provider_desc", "male", "female", "unkown", "total"))

# Clean up data by removing NaN
AE_by_gender = AE_by_gender[~AE_by_gender["code"].isna()]
AE_by_gender.head()
# Out:
#   code                 provider_desc      male    female  unkown     total
# 0  All                       ENGLAND  10210937  10462262  213212  20886411
# 2  Y54              North Of England   3152003   3272078  150690   6574771
# 3  Y55  Midlands And East Of England   2697939   2734073    2425   5434437
# 4  Y56                        London   1947476   2038738   58020   4044234
# 5  Y57              South Of England   2413519   2417373    2077   4832969

# %% [markdown]
# ## Transform data

# %% [markdown]
# Set level of detail between hospitals region and total.

# %%
AE_by_gender = AE_by_gender[~AE_by_gender["code"].isin(["All", "Y54", "Y55", "Y56", "Y57"])]
AE_by_gender.head()
# Out:
#      code                                      provider_desc   male female  \
# 7     REM   Aintree University Hospital NHS Foundation Trust  75516  88374
# 8     RCF                      Airedale NHS Foundation Trust  27921  28899
# 9     RBS          Alder Hey Children's NHS Foundation Trust  31764  26486
# 10    RTK  Ashford And St Peter's Hospitals NHS Foundatio...  48978  50609
# 11  NQT10                                 Assura Reading LLP  17046  22565
#
#    unkown   total
# 7       7  163897
# 8      39   56859
# 9       1   58251
# 10      3   99590
# 11     86   39697

# %% [markdown]
# Upivot data
