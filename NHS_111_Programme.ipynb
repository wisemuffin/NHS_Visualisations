# %% [markdown]
# # NHS 111 Programme
# https://www.england.nhs.uk/statistics/statistical-work-areas/nhs-111-minimum-data-set/nhs-111-minimum-data-set-2017-18/

# %%
# %%html
# <img src='http://www.staffordsurroundsccg.nhs.uk/images/AID_1521_NHS-111-cannock-2_02.09.15_V1_resized.jpg' height="75px" width="50%">
# Out:
# <img src='http://www.staffordsurroundsccg.nhs.uk/images/AID_1521_NHS-111-cannock-2_02.09.15_V1_resized.jpg' height="75px" width="50%">

# %% [markdown]
# ### Objective
# Visualise time series for 111 metrics

# %% [markdown]
# # Set Up

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2017/12/NHS-111-MDS-time-series-to-2017-November-v2.xlsx'
df = pd.read_excel(url, sheet_name='Raw', skiprows=5, header=0, )#, sheet_name='All Attendances - Male', skiprows=3, header=0)
df.rename(columns={'Unnamed: 0':'Concat', 'Unnamed: 1':'Region', 'Unnamed: 2':'Provider Code', 'Unnamed: 3':'Date', 'Unnamed: 4':'Code', 'Unnamed: 5':'Area'}, inplace=True)

# %%
df.head()
# Out:
#         Concat Region Provider Code       Date    Code  \
# 0  111AA440513     ME           DHU 2010-12-01  111AA4
# 1  111AA440544     ME           DHU 2011-01-01  111AA4
# 2  111AA440575     ME           DHU 2011-02-01  111AA4
# 3  111AA440603     ME           DHU 2011-03-01  111AA4
# 4  111AA440634     ME           DHU 2011-04-01  111AA4
#
#                       Area  Population  Total calls offered  \
# 0  NOTTINGHAM CITY NHS 111    299753.0               5782.0
# 1  NOTTINGHAM CITY NHS 111    303899.0               5865.0
# 2  NOTTINGHAM CITY NHS 111    303899.0               3567.0
# 3  NOTTINGHAM CITY NHS 111    303899.0               4942.0
# 4  NOTTINGHAM CITY NHS 111    303899.0               5797.0
#
#    No of abandoned calls  No calls answered   ...     Unnamed: 62  \
# 0                  311.0             5253.0   ...             NaN
# 1                  164.0             5473.0   ...             NaN
# 2                    8.0             3493.0   ...             NaN
# 3                   66.0             4714.0   ...             NaN
# 4                  110.0             5532.0   ...             NaN
#
#    Unnamed: 63  Unnamed: 64  2011-12  2012-13  2013-14  2014-15  2015-16  \
# 0        April          Apr   1343.1  3189.53  18884.4  36029.8  37696.5
# 1          May          May  1162.26  3226.19  18739.9  35891.4  38199.3
# 2         June          Jun  1121.07  3493.87  18423.9  32792.8  32903.6
# 3         July          Jul  1129.03  3096.84  18755.7  31784.7  32782.2
# 4       August          Aug  1143.97  2795.32  17687.7  31731.4  34241.9
#
#    2016-17  2017-18
# 0  39741.2    45968
# 1  42135.5  42161.2
# 2  37499.7  38835.8
# 3  39966.8  40699.9
# 4  36071.2  37615.1
#
# [5 rows x 72 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2604 entries, 0 to 2603
# Data columns (total 72 columns):
# Concat                                                                         2603 non-null object
# Region                                                                         2604 non-null object
# Provider Code                                                                  2603 non-null object
# Date                                                                           2603 non-null datetime64[ns]
# Code                                                                           2603 non-null object
# Area                                                                           2603 non-null object
# Population                                                                     2603 non-null float64
# Total calls offered                                                            2603 non-null float64
# No of abandoned calls                                                          2603 non-null float64
# No calls answered                                                              2603 non-null float64
# Calls answered within 60 secs                                                  2603 non-null float64
# No calls triaged                                                               2603 non-null float64
# Calls transfered to clinical advisor                                           2603 non-null float64
# Warm transfered to clinical advisor                                            2603 non-null float64
# Person offered call back                                                       2603 non-null float64
# Calls back within 10 min                                                       2603 non-null float64
# Calls to a clinician                                                           2603 non-null float64
# Ambulance dispatches                                                           2603 non-null float64
# Recommended to attend A&E                                                      2603 non-null float64
# Recommended to attend primary care                                             2603 non-null float64
# Recommended to contact primary care                                            2603 non-null float64
# Recommended to speak to primary care                                           2603 non-null float64
# Recommended to dental / pharmacy                                               2603 non-null object
# Recommended to dental                                                          2603 non-null object
# Recommended to pharmacy                                                        2603 non-null object
# Recommended to attend other service                                            2603 non-null float64
# Not recommended to attend other service                                        2603 non-null float64
# Given health information                                                       2603 non-null float64
# Recommended home Care                                                          2603 non-null float64
# Recommended non clinical                                                       2603 non-null float64
# Unnamed: 30                                                                    0 non-null float64
# Unnamed: 31                                                                    0 non-null float64
# Unnamed: 32                                                                    0 non-null float64
# Geography                                                                      86 non-null object
# Code                                                                           83 non-null object
# Region Abv                                                                     59 non-null object
# Region Long                                                                    63 non-null object
# Provider                                                                       59 non-null object
# Unnamed: 38                                                                    0 non-null float64
# Unnamed: 39                                                                    0 non-null float64
# Period                                                                         88 non-null datetime64[ns]
# Unnamed: 41                                                                    0 non-null float64
# Unnamed: 42                                                                    0 non-null float64
# Code & Indicator                                                               24 non-null object
# Indicator                                                                      24 non-null object
# Code.1                                                                         24 non-null object
# Unnamed: 46                                                                    0 non-null float64
# Unnamed: 47                                                                    0 non-null float64
# 2017-11-30 00:00:00                                                            22 non-null datetime64[ns]
# Period.1                                                                       88 non-null datetime64[ns]
# Total number of calls offered (left axis)                                      88 non-null float64
# Calls offered per day (left axis)                                              88 non-null float64
# Of calls offered, % abandoned after at least 30 seconds (right axis)           88 non-null float64
# Of calls answered, % in 60 seconds (right axis)                                88 non-null float64
# Answered in 60 sec: 95% standard (right axis)                                  88 non-null float64
# Of answered calls, % calls to a CAS clinician                                  88 non-null float64
# Of calls triaged, % ambulance disposition (5.23)                               88 non-null float64
# Of calls triaged, % recommended to attend A&E (5.24)                           88 non-null float64
# Of calls triaged, % recommended to attend primary and community care (5.25)    88 non-null float64
# Of calls triaged, % recommended to attend other service (5.26)                 88 non-null float64
# Of calls triaged, % not recommended to attend other service (5.27)             88 non-null float64
# Unnamed: 61                                                                    0 non-null float64
# Unnamed: 62                                                                    0 non-null float64
# Unnamed: 63                                                                    124 non-null object
# Unnamed: 64                                                                    108 non-null object
# 2011-12                                                                        112 non-null object
# 2012-13                                                                        104 non-null object
# 2013-14                                                                        104 non-null object
# 2014-15                                                                        104 non-null object
# 2015-16                                                                        104 non-null object
# 2016-17                                                                        109 non-null object
# 2017-18                                                                        80 non-null object
# dtypes: datetime64[ns](4), float64(43), object(25)
# memory usage: 1.4+ MB

# %% [markdown]
# # Visualise the data

# %%
# %%html
# <img src='https://user-images.githubusercontent.com/1280389/30125654-18858b44-9307-11e7-96bc-c37c15b2be51.png' height="75px" width="25%">
# <a href="url">'https://plot.ly'</a>
# Out:
# <img src='https://user-images.githubusercontent.com/1280389/30125654-18858b44-9307-11e7-96bc-c37c15b2be51.png' height="75px" width="25%">
# <a href="url">'https://plot.ly'</a>

# %% [markdown]
# ### Viz with df without index

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

from IPython.display import clear_output # used to stop the duplicate charts

import ipywidgets as widgets
from ipywidgets.widgets import interact, interactive

# %%
metric_options = ['Population', 'Total calls offered', 'No calls answered', 'Calls answered within 60 secs','Ambulance dispatches']
dimension_options = ['Area','Region','Provider Code']

# %%
plotly.offline.init_notebook_mode(connected=False)


def update_chart(dimension_element_picker, dimension_picker):

    # if all is selected in the dimension_element_picker then do not include a dimension in the group by clause
    if dimension_element_picker == 'All':
        df_grouped = df.groupby(by=['Date'], as_index=False).sum()
    else:
        df_filtered = df[df[dimension_picker] == dimension_element_picker]
        df_grouped = df_filtered.groupby(by=[dimension_picker,'Date'], as_index=False).sum()

    # Could allow users to select metrics
    metric_options_selected = metric_options
    
    data = [go.Scatter(
        x = df_grouped['Date'],
        y = df_grouped[metric_options_selected[i]],
        mode = 'lines',
        name = metric_options_selected[i],
#         text = df_grouped[metric_options_selected[i]],
        opacity = 0.8,


    ) for i in range(0, len(metric_options_selected))]

    layout = go.Layout(
        barmode='group',#'group', # switch between stack and group
        title='<b>NHS 111 calls where  </b>'+ dimension_picker+' = '+dimension_element_picker,
        yaxis = dict(
            type = 'log', # switches to a logarythmic scale
            title='<i>Volume</i>'
        ),
#         xaxis=dict(
#             title='<i>Date</i>'
#         )      
    )

    fig = go.Figure(data=data, layout=layout)

    plotly.offline.iplot(fig) # shows the plot offline


Initial_widget_dimension_elements_filter = list(df['Area'].unique())
Initial_widget_dimension_elements_filter.insert(0,'All')

widget_dimension_options = widgets.ToggleButtons(options=dimension_options, description='Options:')
widget_dimension_elements_filter = widgets.Dropdown(options=Initial_widget_dimension_elements_filter, description='Filter:')

def update_dimension_elements_filter(change):
    
    # work around to clear cell output 
    clear_output()
#     display(accordion) # only needed due to bug in ipywidgets version 7 (reverted to version 6 to display widgets on nbvwier)
    
    option_list = list(df[change['new']].unique())
    option_list.insert(0,'All')
    widget_dimension_elements_filter.options = option_list
    update_chart(dimension_element_picker='All', dimension_picker=widget_dimension_options.value)
    
widget_dimension_options.observe(update_dimension_elements_filter, 'value')

def widget_dimension_elements_filter_update(change):
    
    # work around to clear cell output 
    clear_output()
#     display(accordion) # only needed due to bug in ipywidgets version 7 (reverted to version 6 to display widgets on nbvwier)
    
    widget_dimension_elements_filter_selected = change['new']
    update_chart(dimension_element_picker=widget_dimension_elements_filter_selected, dimension_picker=widget_dimension_options.value)

widget_dimension_elements_filter.observe(widget_dimension_elements_filter_update, 'value')

# display(widget_dimension_options, widget_dimension_elements_filter)

# SWITCH from simply displaying widgets to showing them via an accordian
accordion = widgets.Accordion(children=[widget_dimension_options, widget_dimension_elements_filter])
accordion.set_title(0, 'Choose a Dimension To filter by')
accordion.set_title(1, 'Choose a member of that dimension to filter by')
display(accordion)

update_chart(dimension_element_picker='All', dimension_picker='Area')
# Out:
# <div id="9566a170-2251-400c-af8b-788645e6799c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9566a170-2251-400c-af8b-788645e6799c", [{"type": "scatter", "x": ["2010-08-01", "2010-09-01", "2010-10-01", "2010-11-01", "2010-12-01", "2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01", "2016-01-01", "2016-02-01", "2016-03-01", "2016-04-01", "2016-05-01", "2016-06-01", "2016-07-01", "2016-08-01", "2016-09-01", "2016-10-01", "2016-11-01", "2016-12-01", "2017-01-01", "2017-02-01", "2017-03-01", "2017-04-01", "2017-05-01", "2017-06-01", "2017-07-31", "2017-08-31", "2017-09-30", "2017-10-31", "2017-11-30"], "y": [615656.0, 615656.0, 615656.0, 615656.0, 1826797.0, 1840886.0, 1840886.0, 1840886.0, 1840886.0, 1840886.0, 1840886.0, 1840886.0, 1840886.0, 1840886.0, 1840886.0, 2219278.0, 4186475.0, 4202596.0, 4202596.0, 4362596.0, 5313238.0, 5872876.0, 5872876.0, 5872876.0, 6149576.0, 6163811.0, 7487649.0, 8134734.0, 9067370.0, 10262878.0, 11246210.0, 16231950.0, 37612865.0, 37612865.0, 38603366.0, 39768903.0, 39768903.0, 45238394.0, 49735020.0, 50842254.0, 52688348.0, 53125041.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54316618.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 54786327.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55268067.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0, 55640400.0], "mode": "lines", "name": "Population", "opacity": 0.8}, {"type": "scatter", "x": ["2010-08-01", "2010-09-01", "2010-10-01", "2010-11-01", "2010-12-01", "2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01", "2016-01-01", "2016-02-01", "2016-03-01", "2016-04-01", "2016-05-01", "2016-06-01", "2016-07-01", "2016-08-01", "2016-09-01", "2016-10-01", "2016-11-01", "2016-12-01", "2017-01-01", "2017-02-01", "2017-03-01", "2017-04-01", "2017-05-01", "2017-06-01", "2017-07-31", "2017-08-31", "2017-09-30", "2017-10-31", "2017-11-30"], "y": [14972.0, 14781.0, 14489.0, 14148.0, 39773.0, 34460.0, 23854.0, 311 ...

# %% [markdown]
# # Notes for graph
#
# * Uses a logarythmic y axis to help show percent change of metrics
# * Use the acodian user interface to change how to slice NHS 111 Metrics
#
# ### Back Ground
#
# NHS 111 is available 24 hours a day, 7 days a week, 365 days a year to respond to people’s health care needs when:
# *	it’s not a life threatening situation, and therefore is less urgent than a 999 call
# *	the GP isn’t an option, for instance when the caller is away from home
# *	the caller feels they cannot wait and is simply unsure of which service they require
# *	the caller requires reassurance about what to do next.
#
# NHS 111 answers the call, assesses the caller’s needs and determines the most appropriate course of action, including:
# *	for callers facing an emergency, an ambulance will be despatched without delay
# *	where a face to face consultation is required, an appointment will be booked or the caller will be referred to the service that has the appropriate skills and resources to meet their needs in the required timeframe
# *	for callers who do not require a face-to-face consultation, information, advice and reassurance will be provided
# *	where the call is outside the scope of NHS 111, the caller will be signposted to an alternative service
#
# ### Source
# https://www.england.nhs.uk/statistics/statistical-work-areas/nhs-111-minimum-data-set/
#
# ### Bugs
# * Visualisation duplicates charts rather than updates them

# %% [markdown]
# # TO DO
#
# add widgets to:
# * solve duplicate / multiple plots issue
# * select multiple metrics,
#
#
# * also add some annotation and better hover over
#
#
#
# http://ipywidgets.readthedocs.io/en/stable/examples/Widget%20List.html

# %% [markdown]
# # DEV
