# %%
% ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7205-66A1
#
#  Directory of C:\Users\Dave\Jupyter Notebooks\myCS50project
#
# 07/01/2018  09:04    <DIR>          .
# 07/01/2018  09:04    <DIR>          ..
# 07/01/2018  08:09    <DIR>          .ipynb_checkpoints
# 06/01/2018  12:54    <DIR>          Archive
# 07/01/2018  08:39    <DIR>          dash
# 01/01/2018  18:05            13,054 divisions of clinical work.xlsx
# 06/01/2018  14:36         9,820,259 NHS_111_Programme.ipynb
# 06/01/2018  15:24             1,757 NHS_CS50_Project.ipynb
# 28/12/2017  11:18            39,795 NHS_OrgDataServices.ipynb
# 07/01/2018  08:04         4,858,307 NHS_Outpatient_Activity.ipynb
# 06/01/2018  15:08             8,956 NHS_Workforce.ipynb
# 07/01/2018  08:13               555 Untitled.ipynb
#                7 File(s)     14,742,683 bytes
#                5 Dir(s)  125,635,661,824 bytes free

# %%
% lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
% env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\Dave\\AppData\\Roaming',
#  'ASL.LOG': 'Destination=file',
#  'CLICOLOR': '1',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'DESKTOP-K2B3UDT',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'CONDA_DEFAULT_ENV': 'C:\\Users\\Dave\\Anaconda3',
#  'CONDA_PREFIX': 'C:\\Users\\Dave\\Anaconda3',
#  'CONDA_PS1_BACKUP': '$P$G',
#  'GIT_PAGER': 'cat',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\Dave',
#  'IPY_INTERRUPT_EVENT': '1488',
#  'JPY_INTERRUPT_EVENT': '1488',
#  'JPY_PARENT_PID': '1320',
#  'LOCALAPPDATA': 'C:\\Users\\Dave\\AppData\\Local',
#  'LOGONSERVER': '\\\\DESKTOP-K2B3UDT',
#  'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#  'NUMBER_OF_PROCESSORS': '4',
#  'ONEDRIVE': 'C:\\Users\\Dave\\OneDrive',
#  'OS': 'Windows_NT',
# ...
